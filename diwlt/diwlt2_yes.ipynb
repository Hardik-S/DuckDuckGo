# %% [markdown]
# <a href="https://colab.research.google.com/github/Hardik-S/DuckDuckGo/blob/master/diwlt2_yes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# yes, this does work!
#
# now let's try making it one loop

# %%
from fastai.vision import *

# %%
folder = 'mallards'
file = 'mallards.txt'

# %%
#Path block
path = Path('data/ducks')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#Download block
download_images(path/file, dest, max_pics=50, max_workers=0)

# %%
folder = 'domestics'
file = 'domestics.txt'

# %%
#Path block
path = Path('data/ducks')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#Download block
download_images(path/file, dest, max_pics=50, max_workers=0)

# %%
folder = 'rubbers'
file = 'rubbers.txt'

# %%
#Path block
path = Path('data/ducks')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/ducks/domestics.txt'),
#  PosixPath('data/ducks/rubbers.txt'),
#  PosixPath('data/ducks/domestics'),
#  PosixPath('data/ducks/rubbers'),
#  PosixPath('data/ducks/mallards'),
#  PosixPath('data/ducks/mallards.txt')]

# %%
classes = ['mallards','domestics','rubbers']

# %%
#Download block
download_images(path/file, dest, max_pics=50, max_workers=0)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=4, figsize=(10,10))
