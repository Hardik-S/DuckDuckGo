# %% [markdown]
# <a href="https://colab.research.google.com/github/Hardik-S/DuckDuckGo/blob/master/diwlt3_yes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# yes it does work like that, now to import this into main program

# %%
from fastai.vision import *

# %%
i=0
while (i<3):
  print (i)
  if (i==0):
    folder = 'mallards'
    file = 'mallards.txt'
  
  if (i==1):
    folder = 'domestics'
    file = 'domestics.txt'
  
  if (i==2):
    folder = 'rubbers'
    file = 'rubbers.txt'

  #run always
  
  #Path block
  path = Path('data/ducks')
  dest = path/folder
  dest.mkdir(parents=True, exist_ok=True)
  #Download block
  download_images(path/file, dest, max_pics=50, max_workers=0)
  i = i+1
# Out:
# 0
# 1
# 2

# %%
path.ls()
# Out:
# [PosixPath('data/ducks/rubbers.txt'),
#  PosixPath('data/ducks/domestics.txt'),
#  PosixPath('data/ducks/mallards'),
#  PosixPath('data/ducks/domestics'),
#  PosixPath('data/ducks/mallards.txt'),
#  PosixPath('data/ducks/rubbers')]

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=4, figsize=(10,10))
